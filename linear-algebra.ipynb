# %% [markdown]
# #### Linear Algebra
#
# This chapter covers the basics of linear algebra that are needed are for deep learning. It is not meant to be an exhausitve resource for linear algebra but teaches the reader enough to use linear algebra in the context of deep learning.
#
# ## Scalars, Vectors, Matrics and Tensors
#
# 1. **Scalars** - A scalar is just a single number that can take up many different values.
#
# 2. **Vectors** - A vector is an array of numbers. An elemennt in the
# array identified using its index in the ordering. We can think
# of vectors as identifying points in space, each element in the
# vector giving the coordinates along a different axis.
#
# 3. **Matrices** - A matrix is a 2-D array of numbers, so each
# element is identified by two indices instead of just one.
# _A_ represents a row of the matrix. `
#
# 4. **Tensors** - An array fo numbers on a regular gird with a
# variable number of axes is known as a tensor. A tensor with n axes
# can be thought of as an n-dimensional array. Matrices and vectors
# are just tensors with their 2 and 1 axes respectively.
#
#
# ## Matrix operations
#
# __Transpose__ - of a matrix is the mirror image of the matrix across a
# diagonal line called the _main diagonal_, Starting from the upper-left
# corner and going down and to the right. It essentially puts the
# element at position *(i, j)* of a matrix to position
# *(j, i)* of the transpose. Note: the transpose of the transpose of a
# matrix is the matrix itself.
#
# __Addition__ of two matrices, _A + B_ corresponds to the addition of two
# matrices. This is only possible as long as the two matrices have
# the same shape. This operation corresponds to adding elements
# at position *(i, j)* of _A and B_ and assigning their sum to the
# *(i, j)*-th element of the resultant matrix, let's say _C_.
#
# __Adding or multiplying a scalar__ to a matrix corresponds to performing
# the addition/multiplication of the scalar to each element of the matrix.
#
# __Broadcasting__ is a less conventional notation used in deep learning
# wherein we allow the addition of a matrix to a vector yielding another
# matrix. Lets say we perform $C = A + b$ where b is a column vector (a
# vector with just one column). This corresponds to adding to each element
# in $A_{i, :}$ the value at $b_{i}$. In a similar vain, if we were to
# add a row vector to $A$ we would result in the addition of $b_{j}$
# to every column $j$ of A.
#
# __Matrix multiplication__ - the product of matrices A and B resulting in a matrix C.
# In order for this product to be defined $A$ must have the same number of columns
# as $B$ has rows. If $A$ is of shape $m \times n$ and $B$ is of shape
# $n \times p$ then $C$ will be of shape $m \times p$. The notation for
# matrix product is simply $C = AB$ where the product operation
# is defined by $C_{i, j} = \sum_{k} A_{i, k} B_{k, j} $.
#
# __Hadamard product__ is denoted by A ⊙ B and is the element-wise product
# of two matrices. This corresponds to multiplying element _i, j_ of $A$ with
# element _i, j_ of $B$.
#
# The __dot product__ between two vectors $x$ and $y$ of the same
# dimensionality is the matrix product $x^{T}y$. We can think of the matrix
# product $C = AB$ as computing $C_{i, j}$ the dot product between row i of A
# and column j of B.
#
# Matrix products have the following mathematical properties:
#
# * Distributive
# * Associative
#
# Matrix multiplication is not commutative but the dot product between two
# vectors is commutative.
#
# $(AB)^{T} = B^{T}A$
#
# $Ax = B$
#
# To solve this system of linear equations Linear Algebra provides us with the
# matrix inversion operation.
#
# The identity matrix is a matrix that does not change any vector when we multiply
# that vector by that matrix. We denote the idenity matrix that preserves n-dimensional
# vectors as $I_{n}$j. The identity matrix has all the entries along the main diagonal
# as 1 (with the rest of the entries being 0).
#
# The __matrix inverse__ of A is denoted as $A^{-1}$ and it is defined as:
#
# $ A^{-1} A = I_{n} $
#
# which gives us x = $A^{-1}b $
#
# For $A^{-1}$ to exist equation 2.11 must have exactyl one solution for every value of
# b. It is also possible for the system of equations to have no solutions or infinitely
# many solutions. Since if x and y are solutions for a particular b then
#
# $ z = \alpha x + (1 - \alpha) y $
#
# is also a solution.
#
# The span of a set of vectors is the set of all points obtainable by linear combination of
# all the original vectors. Testing whether Ax = b comes down to checking whether b is in
# the span of the columns of A. This particular span is known as the column space, or the
# range of A. To be able to cover $R^{m}$ we need at least m vectors in A. This is a necessary
# condition but not a sufficient one.
#
# Linear Dependence will cause us to need more vectors. In geenral a set of vectors is
# said to be linearly independent if no vector in the set is a linear combination of
# the  other vectors. This guarantees that there is at least one solution for every b
# that belongs to $R^{m}$.
#
# But to have an inverse a matrix must have at most one solution for each value of b.
# To do this we must make sure that that the matrix must have at most m columns.
#
# This means that a matrix needs to be square and the columns need to be linearly
# independent for an inverse to
#
#
#
#
#
#
#
#
#
#
#
#
# ## Suggested Resources
#
# [The Matrix Cookbook](https://www.ics.uci.edu/~welling/teaching\/KernelsICS273B/MatrixCookBook.pdf)
#
# [Shilov](https://cosmathclub.files.wordpress.com/2014/10/georgi-shilov-linear-algebra4.pdf)

# %%
def main():
